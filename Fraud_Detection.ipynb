# %% [markdown]
# # Fraud Detection

# %% [markdown]
# ### Table Contents
# * [Introduction](#chapter1)
# * [Exploratory Data Analysis](#chapter2)
# * [Data Preprocessing](#chapter3)
# * [Main Problem Of The Dataset](#chapter4)
# * [Classic Algorithms Of ML](#chapter5)
# * [Isolation Forest](#chapter6)
# * [AutoEncoders 1 - Deep NN Architecture](#chapter7)
# * [AutoEncoders 2 - Deeper NN Architecture](#chapter8)

# %% [markdown]
# # **Introduction** <a class="anchor"  id="chapter1"></a>

# %%
## ***Auto Encoders 2 - Deeper Neural Networks Architecture*** <a class="anchor"  id="chapter8"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/Fraud Detection Dataset.csv')
df.head()
# Out:
#   Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0             T1     4174             1292.76   ATM Withdrawal
# 1             T2     4507             1554.58   ATM Withdrawal
# 2             T3     1860             2395.02   ATM Withdrawal
# 3             T4     2294              100.10     Bill Payment
# 4             T5     2130             1490.50      POS Payment
#
#    Time_of_Transaction Device_Used       Location  \
# 0                 16.0      Tablet  San Francisco
# 1                 13.0      Mobile       New York
# 2                  NaN      Mobile            NaN
# 3                 15.0     Desktop        Chicago
# 4                 19.0      Mobile  San Francisco
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# 4                                 2           57
#
#    Number_of_Transactions_Last_24H Payment_Method  Fraudulent
# 0                               13     Debit Card           0
# 1                                3    Credit Card           0
# 2                                9            NaN           0
# 3                                4            UPI           0
# 4                                7    Credit Card           0

# %% [markdown]
# # *Exploratory Data Analysis* <a class="anchor"  id="chapter2"></a>

# %% [markdown]
# ## 1st Method using traditionnal EDA

# %%
print("Shape:", df.shape, '\n')
print("Data Types:", df.dtypes, '\n')
for col in df.columns:
    print(f"Unique Data Of The {col}:", df[col].unique())
# Out:
# Shape: (51000, 12)
#
# Data Types: Transaction_ID                       object
# User_ID                               int64
# Transaction_Amount                  float64
# Transaction_Type                     object
# Time_of_Transaction                 float64
# Device_Used                          object
# Location                             object
# Previous_Fraudulent_Transactions      int64
# Account_Age                           int64
# Number_of_Transactions_Last_24H       int64
# Payment_Method                       object
# Fraudulent                            int64
# dtype: object
#
# Unique Data Of The Transaction_ID: ['T1' 'T2' 'T3' ... 'T49998' 'T49999' 'T50000']
# Unique Data Of The User_ID: [4174 4507 1860 ... 4616 2261 4210]
# Unique Data Of The Transaction_Amount: [1292.76 1554.58 2395.02 ...  647.11 2446.65 2867.43]
# Unique Data Of The Transaction_Type: ['ATM Withdrawal' 'Bill Payment' 'POS Payment' 'Bank Transfer'
#  'Online Purchase']
# Unique Data Of The Time_of_Transaction: [16. 13. nan 15. 19.  2.  3. 20.  0. 12. 21. 14.  7.  4. 17. 10.  5.  8.
#  11. 18.  1. 22.  9.  6. 23.]
# Unique Data Of The Device_Used: ['Tablet' 'Mobile' 'Desktop' nan 'Unknown Device']
# Unique Data Of The Location: ['San Francisco' 'New York' nan 'Chicago' 'Boston' 'Houston' 'Miami'
#  'Los Angeles' 'Seattle']
# Unique Data Of The Previous_Fraudulent_Transactions: [0 4 3 2 1]
# Unique Data Of The Account_Age: [119  79 115   3  57  96   6  13 110  66   4  68  25 113  52  65  21  61
#   22  43   7 103   8  71  63  99  81  82   2  85  14  31 108 116  15  51
#   46  94  93  70  10   1  58 112  41  27  19  35  18 106  29 109  16  74
#   28 107  78  44  77  40  20  11  50  45 114  37  48  30  89   9 104  67
#  100 117  47  38  86  34  80  90   5  91  42  83  49 102  54  12  72  69
#   23  36  97  76  95  33 101  59  39 105  98  56 118  62  84  75  92 111
#   32  26  64  60  24  87  73  88  55  17  53]
# Unique Data Of The Number_of_Transactions_Last_24H: [13  3  9  4  7 14 10 12  6  1  8  2 11  5]
# Unique Data Of The Payment_Method: ['Debit Card' 'Credit Card' nan 'UPI' 'Net Banking' 'Invalid Method']
# Unique Data Of The Fraudulent: [0 1]

# %% [markdown]
# #### *Since our main goal is to fully explore the data and find every important feature, which might help the model to predict the accuracy. Firstly, let's handle missing values, and then try to explore categorical and numerical data*

# %%
print('Nan Type Values:\n', df.isnull().sum())
# Out:
# Nan Type Values:
#  Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                         2473
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %%
missing_cols = [col for col in df.columns if df[col].isnull().sum() > 0]

fig, axes = plt.subplots(1, len(missing_cols), figsize=(5 * len(missing_cols), 5))

if len(missing_cols) == 1:
    axes = [axes]

for ax, col in zip(axes, missing_cols):
    sns.histplot(df[col], kde=True, ax=ax, color='red')
    ax.set_title(col)

plt.figure(figsize=(10, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Handling missing values with some random constant string is best in this situation, because only columns which contain numerical features are Transaction_Amount and Time_of_Transaction. So we will handle the categorical featured columns by replacing Nan with constant string, and numerical by replacing mean**

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna('Unknown')
    else:
        df[col] = df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# Transaction_ID                      0
# User_ID                             0
# Transaction_Amount                  0
# Transaction_Type                    0
# Time_of_Transaction                 0
# Device_Used                         0
# Location                            0
# Previous_Fraudulent_Transactions    0
# Account_Age                         0
# Number_of_Transactions_Last_24H     0
# Payment_Method                      0
# Fraudulent                          0
# dtype: int64

# %% [markdown]
# *Now lets review Transaction_ID and User_ID, because their importance in the modelling is questionable*

# %%
print("Unique Data of Transaction_ID:", len(df['Transaction_ID'].unique()))
print("Unique Data Of User_ID:", len(df['User_ID'].unique()))
# Out:
# Unique Data of Transaction_ID: 50000
# Unique Data Of User_ID: 4000

# %% [markdown]
# *All of the values in the transaction column is not important for the prediction, so we can drop them out of the dataset. But the User_ID column holds important information, because one account is used per fraud, so our model will notice it*

# %%
df.drop(['Transaction_ID'], axis=1, inplace=True)

# %% [markdown]
# *Now its time for the statistical review. Since we still have the 'object' type features, we must try encoding. For EDA, the best encoding is LabelEncoder, because we can fully review the options. Other type of encodings will create too much columns, which will mess up the statistics. For modelling, we can use OneHotEncoding.*

# %% [markdown]
# ## *2nd Method using Ydata_profiling library*

# %%
# !pip install ydata-profiling -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 58.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 8.8 MB/s eta 0:00:00

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df,title="Fraud Analysis Report", explorative=True)
profile.to_file("analysis_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#  18%|█▊        | 2/11 [00:00<00:01,  8.66it/s]
#  27%|██▋       | 3/11 [00:00<00:01,  4.13it/s]
#  45%|████▌     | 5/11 [00:00<00:01,  5.03it/s]
#  55%|█████▍    | 6/11 [00:01<00:00,  5.02it/s]
# 100%|██████████| 11/11 [00:01<00:00,  6.44it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### *this library gives us a HTML file that contains all different amont of EDA about our data in which is a great way to explore the data we have in a faster way then the traditionnal way*

# %% [markdown]
# # ***Data Preprocessing*** <a class="anchor"  id="chapter3"></a>

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df_eda = df.copy()
df_train = df.copy()

categorical_features = ['Transaction_Type', 'Device_Used', 'Location', 'Payment_Method']

for col in categorical_features:
    df_eda[col] = le.fit_transform(df_eda[col])

df_train = pd.get_dummies(df_train, columns=categorical_features)

# %%
print('Train Dataset:')
df_train.head()
# Out:
# Train Dataset:
#    User_ID  Transaction_Amount  Time_of_Transaction  \
# 0     4174             1292.76              16.0000
# 1     4507             1554.58              13.0000
# 2     1860             2395.02              11.4884
# 3     2294              100.10              15.0000
# 4     2130             1490.50              19.0000
#
#    Previous_Fraudulent_Transactions  Account_Age  \
# 0                                 0          119
# 1                                 4           79
# 2                                 3          115
# 3                                 4            3
# 4                                 2           57
#
#    Number_of_Transactions_Last_24H  Fraudulent  \
# 0                               13           0
# 1                                3           0
# 2                                9           0
# 3                                4           0
# 4                                7           0
#
#    Transaction_Type_ATM Withdrawal  Transaction_Type_Bank Transfer  \
# 0                             True                           False
# 1                             True                           False
# 2                             True                           False
# 3                            False                           False
# 4                            False                           False
#
#    Transaction_Type_Bill Payment  ...  Location_New York  \
# 0                          False  ...              False
# 1                          False  ...               True
# 2                          False  ...              False
# 3                           True  ...              False
# 4                          False  ...              False
#
#    Location_San Francisco  Location_Seattle  Location_Unknown  \
# 0                    True             False             False
# 1                   False             False             False
# 2                   False             False              True
# 3                   False             False             False
# 4                    True             False             False
#
#    Payment_Method_Credit Card  Payment_Method_Debit Card  \
# 0                       False                       True
# 1                        True                      False
# 2                       False                      False
# 3                       False                      False
# 4                        True                      False
#
#    Payment_Method_Invalid Method  Payment_Method_Net Banking  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
#
#    Payment_Method_UPI  Payment_Method_Unknown
# 0               False                   False
# 1               False                   False
# 2               False                    True
# 3                True                   False
# 4               False                   False
#
# [5 rows x 32 columns]

# %%
print('EDA Dataset:')
df_eda.head()
# Out:
# EDA Dataset:
#    User_ID  Transaction_Amount  Transaction_Type  Time_of_Transaction  \
# 0     4174             1292.76                 0              16.0000
# 1     4507             1554.58                 0              13.0000
# 2     1860             2395.02                 0              11.4884
# 3     2294              100.10                 2              15.0000
# 4     2130             1490.50                 4              19.0000
#
#    Device_Used  Location  Previous_Fraudulent_Transactions  Account_Age  \
# 0            2         6                                 0          119
# 1            1         5                                 4           79
# 2            1         8                                 3          115
# 3            0         1                                 4            3
# 4            1         6                                 2           57
#
#    Number_of_Transactions_Last_24H  Payment_Method  Fraudulent
# 0                               13               1           0
# 1                                3               0           0
# 2                                9               5           0
# 3                                4               4           0
# 4                                7               0           0

# %% [markdown]
# #### *Now, lets check out correlations between features. Lets make figure of this heatmap 12x12, because we have 12 feature.*

# %%
plt.figure(figsize=(12,12))

sns.heatmap(df_eda.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### *The correlation between target variable and features are too low. There might be several reasons for it, but main problem, which could be the problem of the dataset is Randomness/Outliers. Lets overview boxplots and check if the data is too noisy.*

# %% [markdown]
# ### Main Problem Of The Dataset

# %%
sns.countplot(x=df['Fraudulent'])
# Out:
# <Axes: xlabel='Fraudulent', ylabel='count'>

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(df_eda.drop(['Fraudulent'], axis=1), df_eda['Fraudulent'])
print(mi_scores)
# Out:
# [0.00077481 0.         0.00254952 0.00079724 0.00097988 0.00099353
#  0.00353572 0.         0.00112013 0.00142942]

# %% [markdown]
# #### MI Scores of several columns are zero, which might suggest the that these features are irrelevant to target variable

# %%
important_features = df_eda.drop(['Fraudulent'], axis=1).columns[mi_scores > 0]
important_features
# Out:
# Index(['User_ID', 'Transaction_Type', 'Time_of_Transaction', 'Device_Used',
#        'Location', 'Previous_Fraudulent_Transactions',
#        'Number_of_Transactions_Last_24H', 'Payment_Method'],
#       dtype='object')

# %% [markdown]
# Lets check boxplots if theres outliers in data

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(important_features), figsize=(20, 5))

for ax, col in zip(axes, important_features):
    sns.boxplot(x=df_eda[col], ax=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### There arent significant outliers in this important columns

# %% [markdown]
# **The conclusion which we made from the Exploratory Data Analysis is that the dataset has unbalanced labels for target variable. Problem can be handled by several methods:**
# * Oversampling Minority Class with SMOTE (Best for Small Datasets)
# * Undersampling Majority Class (Risky but Fast)
# * Adjusting Class Weights (Best for Large Datasets)
# * Anomaly Detection (Used for Fraud/Failure Detection)

# %% [markdown]
# ## ***Modelling with Classic Machine Learning Algorithms*** <a class="anchor"  id="chapter5"></a>

# %%
df_train.shape
# Out:
# (51000, 32)

# %%
def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
# !pip install lightgbm
# !pip install catboost
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lightgbm) (1.16.3)
# Collecting catboost
#   Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
import pandas as pd
from tqdm import tqdm

scaler = StandardScaler()

X = df_train.drop(['Fraudulent'], axis=1)
Y = df_train['Fraudulent']

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X, Y)
X_scaled = scaler.fit_transform(X_train_resampled)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_train_resampled, test_size=0.2, random_state=42, stratify=y_train_resampled)

models = {
    "Logistic Regression": LogisticRegression(C=1.0, solver="liblinear", max_iter=500, class_weight="balanced"),
    "Random Forest": RandomForestClassifier(n_estimators=300, max_depth=12, min_samples_split=5, class_weight="balanced_subsample", random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=10, min_samples_split=10, criterion="gini", class_weight="balanced", random_state=42),
    "XGBoost": XGBClassifier(n_estimators=500, learning_rate=0.03, max_depth=7, scale_pos_weight=5, subsample=0.8, colsample_bytree=0.8, eval_metric="logloss", use_label_encoder=False),
    "LightGBM": LGBMClassifier(n_estimators=500, learning_rate=0.03, max_depth=7, num_leaves=60, min_data_in_leaf=5, force_col_wise=True, scale_pos_weight=5, verbose=-1),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=500, learning_rate=0.03, max_depth=7, min_samples_split=5),
    "SGD Classifier": SGDClassifier(loss="log_loss", penalty="l2", alpha=0.0001, max_iter=2000, tol=1e-4, class_weight="balanced"),
    "CatBoost": CatBoostClassifier(iterations=500, learning_rate=0.03, depth=7, l2_leaf_reg=5, scale_pos_weight=5, verbose=0),
}

results = []
for name, model in tqdm(models.items(), desc="Training Models", total=len(models)):
    model.fit(X_train_resampled, y_train_resampled)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average="weighted")
    roc_auc = roc_auc_score(y_test, y_pred)

    results.append({"Model": name, "Accuracy": accuracy, "F1 Score": f1, "ROC AUC": roc_auc})

    plot_confusion_matrix(y_test, y_pred, name)

results_df = pd.DataFrame(results).sort_values(by="F1 Score", ascending=False)
print(results_df)
# Out:
# Training Models:   0%|          | 0/8 [00:00<?, ?it/s]
# Training Models:  12%|█▎        | 1/8 [00:02<00:19,  2.77s/it]
# Training Models:  25%|██▌       | 2/8 [00:46<02:39, 26.65s/it]
# Training Models:  38%|███▊      | 3/8 [00:46<01:13, 14.77s/it]
# Training Models:  50%|█████     | 4/8 [00:52<00:44, 11.21s/it]
# Training Models:  62%|██████▎   | 5/8 [01:00<00:30, 10.01s/it]
# Training Models:  75%|███████▌  | 6/8 [05:15<03:06, 93.24s/it]
# Training Models:  88%|████████▊ | 7/8 [05:17<01:03, 63.41s/it]
# Training Models: 100%|██████████| 8/8 [05:32<00:00, 41.58s/it]
#                  Model  Accuracy  F1 Score   ROC AUC
# 3              XGBoost  0.970148  0.970125  0.970148
# 5    Gradient Boosting  0.961281  0.961264  0.961281
# 7             CatBoost  0.958909  0.958840  0.958909
# 4             LightGBM  0.958548  0.958537  0.958548
# 1        Random Forest  0.957878  0.957803  0.957878
# 6       SGD Classifier  0.916839  0.916512  0.916839
# 2        Decision Tree  0.899515  0.898490  0.899515
# 0  Logistic Regression  0.729480  0.708120  0.729480

# %%
results_df
# Out:
#                  Model  Accuracy  F1 Score   ROC AUC
# 3              XGBoost  0.970148  0.970125  0.970148
# 5    Gradient Boosting  0.961281  0.961264  0.961281
# 7             CatBoost  0.958909  0.958840  0.958909
# 4             LightGBM  0.958548  0.958537  0.958548
# 1        Random Forest  0.957878  0.957803  0.957878
# 6       SGD Classifier  0.916839  0.916512  0.916839
# 2        Decision Tree  0.899515  0.898490  0.899515
# 0  Logistic Regression  0.729480  0.708120  0.729480

# %% [markdown]
# **Since the imbalance continues, lets try using isolation forest, which is best way to handle imbalanced data**

# %% [markdown]
# ## ***Isolation Forest*** <a class="anchor"  id="chapter6"></a>

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn) (3.6.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE

# ============================================
# ASSUMING YOU START WITH:
# X = original features (DataFrame or array)
# y = original target (0 = normal, 1 = fraud)
# ============================================

print(f"Original data: X={X.shape}, Y={len(Y)}")

# STEP 1: SPLIT FIRST (before scaling or resampling!)
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42, stratify=Y
)

print(f"After split: X_train={X_train.shape}, X_test={X_test.shape}")

# STEP 2: SCALE (fit on train, transform both)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# STEP 3: RESAMPLE ONLY TRAINING DATA
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

print(f"After SMOTE: X_train_resampled={X_train_resampled.shape}")
print(f"Class distribution: {np.bincount(y_train_resampled)}")

# STEP 4: TRAIN RANDOM FOREST (memory efficient!)
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    class_weight='balanced',  # Handles remaining imbalance
    max_depth=20,
    n_jobs=-1
)

rf.fit(X_train_resampled, y_train_resampled)

# STEP 5: PREDICT ON ORIGINAL (SCALED) TEST SET
y_pred = rf.predict(X_test_scaled)
y_pred_proba = rf.predict_proba(X_test_scaled)[:, 1]

# Verify shapes match
print(f"\ny_test: {len(y_test)}, y_pred: {len(y_pred)}")  # Should be equal!

# STEP 6: EVALUATE
print("\n" + "="*50)
print(classification_report(y_test, y_pred, target_names=["Normal", "Fraud"]))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Class 0", "Class 1"],
            yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix - Random Forest")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()
# Out:
# Original data: X=(51000, 31), Y=51000
# After split: X_train=(40800, 31), X_test=(10200, 31)
# After SMOTE: X_train_resampled=(77584, 31)
# Class distribution: [38792 38792]
#
# y_test: 10200, y_pred: 10200
#
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal       0.95      0.98      0.96      9698
#        Fraud       0.10      0.05      0.07       502
#
#     accuracy                           0.93     10200
#    macro avg       0.53      0.51      0.52     10200
# weighted avg       0.91      0.93      0.92     10200

# %% [markdown]
# **Isolation Forest gave little bit better performance on Class 1 (27 Right), but lets try better fixing the issue arised in the imbalanced data**

# %% [markdown]
# **Lets use AutoEncoders, which is one of the best way to anomaly detection**

# %% [markdown]
# ## ***AutoEncoders 1 - Deep Neural Network Architecture*** <a class="anchor"  id="chapter7"></a>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress TF logging
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # Force CPU only (prevents GPU memory crash)

# Limit TensorFlow memory growth BEFORE importing tensorflow
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix
import tensorflow as tf

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print('GPU not found. Using CPU.')
else:
    print(f'GPU found: {device_name}')
# Out:
# GPU found: /device:GPU:0

# %%
X = df_train.drop(['Fraudulent'], axis=1)
Y = df_train['Fraudulent']
X, Y = smote.fit_resample(X, Y)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42, stratify=Y)

model = Sequential([
    Dense(512, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.4),
    BatchNormalization(),

    Dense(256, activation='relu'),
    Dropout(0.4),
    BatchNormalization(),

    Dense(128, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),

    Dense(64, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),

    Dense(32, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),

    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=128, validation_data=(X_test, y_test), verbose=1)

y_pred = (model.predict(X_test) > 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average="weighted")
roc_auc = roc_auc_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
# Out:
# Epoch 1/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.9016 - loss: 0.2640 - val_accuracy: 0.9606 - val_loss: 0.1514
# Epoch 2/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.
50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9707 - loss: 0.1116 - val_accuracy: 0.9715 - val_loss: 0.1086
# Epoch 35/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9706 - loss: 0.1112 - val_accuracy: 0.9720 - val_loss: 0.1087
# Epoch 36/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9709 - loss: 0.1102 - val_accuracy: 0.9718 - val_loss: 0.1082
# Epoch 37/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9709 - loss: 0.1109 - val_accuracy: 0.9718 - val_loss: 0.1078
# Epoch 38/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9709 - loss: 0.1102 - val_accuracy: 0.9722 - val_loss: 0.1077
# Epoch 39/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9712 - loss: 0.1098 - val_accuracy: 0.9718 - val_loss: 0.1078
# Epoch 40/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9711 - loss: 0.1096 - val_accuracy: 0.9724 - val_loss: 0.1069
# Epoch 41/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9711 - loss: 0.1086 - val_accuracy: 0.9720 - val_loss: 0.1073
# Epoch 42/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9713 - loss: 0.1084 - val_accuracy: 0.9727 - val_loss: 0.1063
# Epoch 43/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9714 - loss: 0.1085 - val_accuracy: 0.9726 - val_loss: 0.1060
# Epoch 44/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9716 - loss: 0.1082 - val_accuracy: 0.9720 - val_loss: 0.1069
# Epoch 45/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9716 - loss: 0.1083 - val_accuracy: 0.9727 - val_loss: 0.1056
# Epoch 46/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9714 - loss: 0.1081 - val_accuracy: 0.9732 - val_loss: 0.1053
# Epoch 47/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9717 - loss: 0.1077 - val_accuracy: 0.9728 - val_loss: 0.1055
# Epoch 48/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9718 - loss: 0.1069 - val_accuracy: 0.9731 - val_loss: 0.1053
# Epoch 49/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9716 - loss: 0.1076 - val_accuracy: 0.9725 - val_loss: 0.1052
# Epoch 50/50
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9721 - loss: 0.1066 - val_accuracy: 0.9731 - val_loss: 0.1051
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Accuracy: 0.9731
# F1 Score: 0.9731
# ROC AUC: 0.9731
# Confusion Matrix:

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
# Out:
# <Axes: >

# %% [markdown]
# **It still doesn't work. Adding deeper architecture might help it off.**

# %% [markdown]
# ## ***Auto Encoders 2 - Deeper Neural Networks Architecture*** <a class="anchor"  id="chapter8"></a>

# %%
model = Sequential([
    Dense(1024, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.5),
    BatchNormalization(),

    Dense(512, activation='relu'),
    Dropout(0.5),
    BatchNormalization(),

    Dense(256, activation='relu'),
    Dropout(0.4),
    BatchNormalization(),

    Dense(128, activation='relu'),
    Dropout(0.4),
    BatchNormalization(),

    Dense(64, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),

    Dense(32, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),

    Dense(16, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),

    Dense(8, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),

    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test), verbose=1)

y_pred = (model.predict(X_test) > 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average="weighted")
roc_auc = roc_auc_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Epoch 1/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.8710 - loss: 0.3217 - val_accuracy: 0.9604 - val_loss: 0.1432
# Epoch 2/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9618 - loss: 0.1535 - val_accuracy: 0.9688 - val_loss: 0.1183
# Epoch 3/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9648 - loss: 0.1389 - val_accuracy: 0.9676 - val_loss: 0.1212
# Epoch 4/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9659 - loss: 0.1342 - val_accuracy: 0.9684 - val_loss: 0.1196
# Epoch 5/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9654 - loss: 0.1336 - val_accuracy: 0.9694 - val_loss: 0.1165
# Epoch 6/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9672 - loss: 0.1287 - val_accuracy: 0.9680 - val_loss: 0.1202
# Epoch 7/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9676 - loss: 0.1269 - val_accuracy: 0.9706 - val_loss: 0.1133
# Epoch 8/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9680 - loss: 0.1261 - val_accuracy: 0.9706 - val_loss: 0.1134
# Epoch 9/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9673 - loss: 0.1275 - val_accuracy: 0.9705 - val_loss: 0.1139
# Epoch 10/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9676 - loss: 0.1267 - val_accuracy: 0.9702 - val_loss: 0.1146
# Epoch 11/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9687 - loss: 0.1240 - val_accuracy: 0.9709 - val_loss: 0.1128
# Epoch 12/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9682 - loss: 0.1251 - val_accuracy: 0.9709 - val_loss: 0.1128
# Epoch 13/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9688 - loss: 0.1234 - val_accuracy: 0.9707 - val_loss: 0.1134
# Epoch 14/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9685 - loss: 0.1241 - val_accuracy: 0.9705 - val_loss: 0.1140
# Epoch 15/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9691 - loss: 0.1214 - val_accuracy: 0.9709 - val_loss: 0.1128
# Epoch 16/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9684 - loss: 0.1247 - val_accuracy: 0.9709 - val_loss: 0.1129
# Epoch 17/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9690 - loss: 0.1221 - val_accuracy: 0.9708 - val_loss: 0.1130
# Epoch 18/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9692 - loss: 0.1217 - val_accuracy: 0.9707 - val_loss: 0.1134
# Epoch 19/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9682 - loss: 0.1253 - val_accuracy: 0.9707 - val_loss: 0.1135
# Epoch 20/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9688 - loss: 0.1220 - val_accuracy: 0.9705 - val_loss: 0.1138
# Epoch 21/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9684 - loss: 0.1236 - val_accuracy: 0.9709 - val_loss: 0.1126
# Epoch 22/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9690 - loss: 0.1220 - val_accuracy: 0.9698 - val_loss: 0.1159
# Epoch 23/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9689 - loss: 0.1226 - val_accuracy: 0.9705 - val_loss: 0.1140
# Epoch 24/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9688 - loss: 0.1210 - val_accuracy: 0.9709 - val_loss: 0.1127
# Epoch 25/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9689 - loss: 0.1220 - val_accuracy: 0.9710 - val_loss: 0.1126
# Epoch 26/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9695 - loss: 0.1198 - val_accuracy: 0.9710 - val_loss: 0.1126
# Epoch 27/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9691 - loss: 0.1205 - val_accuracy: 0.9709 - val_loss: 0.1128
# Epoch 28/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9691 - loss: 0.1218 - val_accuracy: 0.9707 - val_loss: 0.1133
# Epoch 29/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9692 - loss: 0.1208 - val_accuracy: 0.9710 - val_loss: 0.1125
# Epoch 30/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9698 - loss: 0.1184 - val_accuracy: 0.9710 - val_loss: 0.1125
# Epoch 31/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9694 - loss: 0.1202 - val_accuracy: 0.9710 - val_loss: 0.1125
# Epoch 32/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9695 - loss: 0.1190 - val_accuracy: 0.9710 - val_loss: 0.1125
# Epoch 33/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9692 - loss: 0.1201 - val_accuracy: 0.9707 - val_loss: 0.1133
# Epoch 34/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9693 - loss: 0.1197 - val_accuracy: 0.9706 - val_loss: 0.1136
# Epoch 35/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9689 - loss: 0.1214 - val_accuracy: 0.9710 - val_loss: 0.1125
# Epoch 36/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9696 - loss: 0.1191 - val_accuracy: 0.9709 - val_loss: 0.1128
# Epoch 37/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9691 - loss: 0.1205 - val_accuracy: 0.9708 - val_loss: 0.1129
# Epoch 38/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9693 - loss: 0.1197 - val_accuracy: 0.9710 - val_loss: 0.1125
# Epoch 39/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9694 - loss: 0.1194 - val_accuracy: 0.9709 - val_loss: 0.1126
# Epoch 40/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9692 - loss: 0.1203 - val_accuracy: 0.9709 - val_loss: 0.1125
# Epoch 41/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.